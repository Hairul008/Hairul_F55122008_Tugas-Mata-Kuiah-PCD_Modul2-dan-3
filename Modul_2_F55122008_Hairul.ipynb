# %% [markdown]
# <a href="https://colab.research.google.com/github/Hairul008/Hairul_F55122008_Tugas-Mata-Kuiah-PCD_Modul2-dan-3/blob/main/Modul_2_F55122008_Hairul.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("/content/Mommogram.tiff")

# %%
img_1 = 255 - img

# %%
plt.subplot(2, 2, 1)
plt.imshow(img)
plt.title('Original Image')
plt.subplot(2, 2, 2)
plt.imshow(img_1)
plt.title('Image Negative')
# Out:
# Text(0.5, 1.0, 'Image Negative')
